# %%
import pandas as pd
import numpy as np
import pickle,itertools,sys,pdb
from alphamind.data.processing import factor_processing
from alphamind.data.standardize import standardize
from alphamind.data.winsorize import winsorize_normal
from ultron.factor.combine.combine_engine import CombineEngine
from ultron.factor.genetic.mutation_factors import GeneticMutationFactors
from ultron.factor.genetic.accumulators import transform
from ultron.sentry.Analysis.SecurityValueHolders import SecurityCurrentValueHolder
import warnings
warnings.filterwarnings("ignore")

# %%
# 以等权合成因子的IC值作为分数判断 (注意:系统是以分数倒序排序来进行种群筛选，若类似IC带有方向性可以使用绝对值)
def equal_combine(factor_df, factor_list):
    factor_df = factor_df.copy()
    ndiff_field = [i for i in list(set(factor_df.columns)) if i not in factor_list]
    #合成前数据预处理
    alpha_res = []
    grouped = factor_df.groupby(['trade_date'])
    for k, g in grouped:
        ret_preprocess = factor_processing(g[factor_list].fillna(0).values,
                                       pre_process=[winsorize_normal, standardize])
        f = pd.DataFrame(ret_preprocess, columns=factor_list)
        for k in ndiff_field:
            f[k] = g[k].values
        alpha_res.append(f)
    total_data = pd.concat(alpha_res)
    total_data = factor_df
    total_data['conmbine'] = total_data[factor_list].mean(axis=1).values
    score = np.corrcoef(total_data['conmbine'].fillna(0).values, total_data['ret'].fillna(0).values)[0,1]
    return abs(score)

# %%
# 读取数据
with open('factor_data.pkl','rb') as file2:
    total_data = pickle.load(file2)
total_data.head(10)
# Out:
#   trade_date    code  ROEAfterNonRecurring       CHV        DROE       IVR  \
# 0 2018-09-18      10           -105.734422 -0.660606 -202.841612  0.272982
# 1 2018-09-18     852             -1.402939 -0.733333 -123.396084  0.016266
# 2 2018-09-18    2019             19.556671  0.273557  -18.170500  0.567898
# 3 2018-09-18    2278              0.313534 -0.866667  -77.894469  0.214677
# 4 2018-09-18    2380              4.434590 -0.820672   -2.934867  0.540656
# 5 2018-09-18    2468             20.605487 -0.915152   -0.400065  0.606586
# 6 2018-09-18    2624             17.539010 -0.515152    4.299128  0.321421
# 7 2018-12-03  300674                   NaN -0.696970         NaN       NaN
# 8 2018-09-18    2850              1.569706 -0.522799  -64.921336  0.340336
# 9 2018-09-18  300004             -8.701008 -0.878788 -193.875500  0.229192
#
#    EPAfterNonRecurring  DROEAfterNonRecurring    CFinc1   alpha_1  ...  \
# 0            -0.283813              -5.042790 -0.715046 -0.275493  ...
# 1            -0.003703              58.969788 -0.715046  0.171365  ...
# 2             0.097143              -4.336328 -0.715046  0.587883  ...
# 3             0.001169             119.794377 -0.715046 -0.842086  ...
# 4             0.031446              -1.762149 -0.715046 -0.665430  ...
# 5             0.059930               2.539710  0.346927 -0.013798  ...
# 6             0.046763               3.378517  0.484389 -0.317983  ...
# 7             0.012046                    NaN -0.602760  0.539310  ...
# 8             0.008644             -61.217660 -0.715046 -0.191557  ...
# 9            -0.136293               6.550788 -0.715046 -0.259448  ...
#
#    alpha_184  alpha_185  alpha_186  alpha_187  alpha_188  alpha_189  \
# 0   1.833226   0.993045  47.560620   1.860000 -45.363736   0.057778
# 1   1.618495   0.188641  75.607325   8.310000  19.319093   0.335556
# 2   0.450731   0.237612  59.255802   1.988267 -13.381817   0.348163
# 3   1.202937   0.101420  51.405364   3.020000 -21.761117   0.109167
# 4   1.039419   0.632280  20.042926   1.270000  12.386432   0.072222
# 5   0.640416   0.208345  16.081620   5.200000  10.875756   0.216944
# 6   0.177497   0.337294  21.211366   8.870000  -4.847316   0.270833
# 7   0.981496   0.029121        NaN        NaN   5.805438   1.696944
# 8   0.915306   0.452043  40.196448   2.560000 -26.432105   0.376667
# 9   0.548041   0.090409  33.340708   1.870000   3.492951   0.096667
#
#    alpha_190  alpha_191       ret  negMarketValue
# 0  -0.580667  -0.609058  0.010215    2.542974e+09
# 1  -1.094852  -1.018469  0.072496    6.364398e+09
# 2   0.400129  -1.125340  0.033667    9.262848e+09
# 3   0.431720   0.137349 -0.017744    2.738049e+09
# 4  -0.409236   0.745425  0.020334    1.744613e+09
# 5  -0.721486  -0.080343  0.119134    5.454397e+09
# 6  -0.372736   0.686561  0.023912    1.137201e+10
# 7        NaN        NaN -0.221687    1.509177e+09
# 8   0.397108  -0.889158  0.064603    1.795720e+09
# 9  -0.427337  -0.962769  0.227645    1.778908e+09
#
# [10 rows x 202 columns]

# %%
diff_filed = ['trade_date','code','ret'] # 非因子列
factor_columns = [i for i in list(set(total_data.columns)) if i not in ['trade_date','code','ret']] # 因子列
total_data = total_data.sort_values(by=['trade_date','code'],ascending=True)

# %%
# 将原始特征进行分类，分位两类，一类较强类，一类较弱类。可通过前期处理比如IR分数分类等方法，此处采用随机分类
point = int(np.random.uniform(0, len(factor_columns))/2)
ori_field = factor_columns[:point]
add_field = factor_columns[point:]

# %%
# 定义遗传对象
mutation_factors = GeneticMutationFactors(0.4, #添加第一类特征概率
                                          0.2, #添加第二类特征概率
                                          0.9, #突变概率
                                          0.00001,#收敛值大小，即子代最好种群和父代最好种群分数差值，若小于改值则停止繁衍
                                          generation=6, # 繁衍代数
                                          group_num=10, # 每代种群数
                                          objective=equal_combine)

# %%
# %%time
#第一种返回最后一代最好前group_num种群
field_group = mutation_factors.genetic_run(total_data, diff_filed = diff_filed, strong_field = ori_field, 
                             weak_field = add_field, is_best=False)
# Out:
# 种群数20, 种群均分:0.006104
# 繁衍代数:1,最好分数:0.017472,1(0.017472)和0(0.000000)最好组分数差值0.017472,1代最好最差种群分数差值0.127297
# 种群数20, 种群均分:0.010823
# 繁衍代数:2,最好分数:0.034932,2(0.034932)和1(0.017472)最好组分数差值0.017460,2代最好最差种群分数差值0.162306
# 种群数20, 种群均分:0.017961
# 繁衍代数:3,最好分数:0.034945,3(0.034945)和2(0.034932)最好组分数差值0.000013,3代最好最差种群分数差值0.079202
# 种群数20, 种群均分:0.023556
# 繁衍代数:4,最好分数:0.034945,4(0.034945)和3(0.034945)最好组分数差值-0.000000,4代最好最差种群分数差值0.058848
# 种群数20, 种群均分:0.032304
# 繁衍代数:5,最好分数:0.034945,5(0.034945)和4(0.034945)最好组分数差值0.000000,5代最好最差种群分数差值0.000059
# 种群数20, 种群均分:0.034929
# 繁衍代数:6,最好分数:0.034945,6(0.034945)和5(0.034945)最好组分数差值0.000000,6代最好最差种群分数差值0.000059
# CPU times: user 4min 14s, sys: 1.33 s, total: 4min 15s
# Wall time: 4min 14s

# %%
#展示种群繁衍过程，并将因子变异过程转化为算子，用于样本外数据直接计算得到新因子
# transform(i,is_formula)# is_formula为False返回公式字符串，is_formula为True返回可执行公式
formula_group = {}
for k, g in field_group.items():
    formula_group[k] = [transform(i,is_formula=True) for i in g]

# %%
## 合成因子 此处使用的等权合成，读取种群编号
formual_sets = None
for formual in formula_group[50][28:29]:
    if formual_sets is None:
        formual_sets = formual
    else:
        formual_sets += formual
formual_sets.transform(total_data.set_index('trade_date'), category_field='code', dropna=False).head()
# Out:
#             transformed  code
# trade_date
# 2018-08-31          NaN     1
# 2018-08-31          NaN     2
# 2018-08-31          NaN     4
# 2018-08-31          NaN     5
# 2018-08-31          NaN     6

# %%
s = formula_group[50][28]
print(s)
# Out:
# ''\text{alpha_138}''

# %%
formula_group[389]
# Out:
# ["SecurityCurrentValueHolder('alpha_42')",
#  "SecurityCurrentValueHolder('alpha_24')",
#  "SecurityCurrentValueHolder('alpha_185')",
#  "SecurityCurrentValueHolder('alpha_66')",
#  "SecurityCurrentValueHolder('alpha_157')",
#  "SecurityCurrentValueHolder('alpha_98')",
#  "SecurityCurrentValueHolder('alpha_38')",
#  "SecurityCurrentValueHolder('alpha_25')",
#  "SecurityCurrentValueHolder('alpha_28')",
#  "SecurityCurrentValueHolder('alpha_139')",
#  "SecurityCurrentValueHolder('alpha_189')",
#  "SecurityCurrentValueHolder('alpha_119')",
#  "SecurityCurrentValueHolder('alpha_169')",
#  "SecurityCurrentValueHolder('alpha_54')",
#  "SecurityCurrentValueHolder('alpha_34')",
#  "SecurityCurrentValueHolder('alpha_73')",
#  "SecurityCurrentValueHolder('alpha_186')",
#  "SecurityCurrentValueHolder('alpha_149')",
#  "SecurityCurrentValueHolder('alpha_71')",
#  "SecurityCurrentValueHolder('alpha_191')",
#  "SecurityCurrentValueHolder('alpha_160')",
#  "SecurityCurrentValueHolder('alpha_51')",
#  "SecurityCurrentValueHolder('alpha_90')",
#  "SecurityCurrentValueHolder('alpha_109')",
#  "SecurityCurrentValueHolder('alpha_137')",
#  "SecurityCurrentValueHolder('alpha_41')",
#  "SecurityCurrentValueHolder('alpha_105')",
#  "CSPercentileSecurityValueHolder('EPAfterNonRecurring')",
#  "SecuritySqrtValueHolder('alpha_102')",
#  "SecurityCurrentValueHolder('alpha_161')",
#  "SecuritySignValueHolder('alpha_93')",
#  "SecurityDiffValueHolder('alpha_141')",
#  "CSPercentileSecurityValueHolder(SecuritySqrtValueHolder('alpha_49'))",
#  "SecurityDiffValueHolder(SecuritySignValueHolder(SecurityCeilValueHolder('alpha_117')))",
#  "SecurityNormInvValueHolder(SecuritySigmoidValueHolder('alpha_173'))",
#  "SecurityExpValueHolder(SecurityTanhValueHolder(CSRankedSecurityValueHolder(SecurityDiffValueHolder('alpha_189'))))",
#  "CSPercentileSecurityValueHolder('alpha_78')",
#  "SecurityNormInvValueHolder(SecurityDiffValueHolder('alpha_117'))",
#  "SecuritySignValueHolder(SecurityRoundValueHolder(SecuritySqrtValueHolder('alpha_117')))",
#  "SecurityNormInvValueHolder(SecurityAbsValueHolder(SecurityLogValueHolder('EPAfterNonRecurring')))",
#  "SecurityAbsValueHolder('alpha_88')",
#  "SecurityAbsValueHolder(SecurityRoundValueHolder(SecuritySigmoidValueHolder(SecurityLogValueHolder(SecuritySqrtValueHolder('ROEAfterNonRecurring')))))"]
